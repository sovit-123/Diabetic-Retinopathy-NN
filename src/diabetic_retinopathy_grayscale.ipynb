# %%
# from google.colab import drive
# drive.mount('/gdrive')

# %%
from fastai.vision import *
from datetime import datetime

import matplotlib.pyplot as plt

# %%
date = datetime.now().date()
time_now = datetime.now().time()
time = f"{time_now.hour}-{time_now.minute}-{time_now.second}"

# %%
'''
Severity Levels

0 - 'No_DR',
1 - 'Mild',
2 - 'Moderate',
3 - 'Severe',
4 - 'Proliferate_DR'
'''

classes = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']

# %%
path = Path('../input/grayscale_images')
path.ls()
# Out:
# [WindowsPath('../input/grayscale_images/export.pkl'),
#  WindowsPath('../input/grayscale_images/Mild'),
#  WindowsPath('../input/grayscale_images/Moderate'),
#  WindowsPath('../input/grayscale_images/No_DR'),
#  WindowsPath('../input/grayscale_images/Proliferate_DR'),
#  WindowsPath('../input/grayscale_images/Severe')]

# %%
# remove the images that we cannot open
# for c in classes:
#     print(c)
#     verify_images(path/c, delete=True, max_size=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2, 
                                  ds_tfms=get_transforms(), size=224, 
                                  num_workers=4, bs=16).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']

# %%
data.show_batch(rows=3, figsize=(10, 7))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe'], 5, 2930, 732)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, model_dir='../')
# path = users/.cache/torch

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.188461</td>
#       <td>0.812697</td>
#       <td>0.275956</td>
#       <td>01:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
plt.savefig(f"../models/plots/{date}_{time}_loss_grayscale_stage1.png")
plt.show()

# %%
learn.save(f"../models/{date}_{time}_grayscale_stage_1")

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()
plt.savefig(f"../models/plots/{date}_{time}_lrfind_loss_grayscale.png")
plt.show()

# %%
learn.fit_one_cycle(1, max_lr=slice(1e-05, 1e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.917010</td>
#       <td>0.692467</td>
#       <td>0.243169</td>
#       <td>01:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f"../models/{date}_{time}_grayscale_stage_2")

# %%
learn.load(f"../models/{date}_{time}_grayscale_stage_2")
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2930 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Mild,Mild,Mild,Mild,Mild
# Path: ..\input\grayscale_images;
#
# Valid: LabelList (732 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# No_DR,Moderate,Moderate,Moderate,Moderate
# Path: ..\input\grayscale_images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()
plt.savefig(f"../models/plots/{date}_{time}_confusion_matrix_grayscale.png")

# %%
learn.export(f"{date}_{time}_grayscale.pkl")

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image('../input/test_images/ffec9a18a3ce.png')
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-f6cdca0971e8> in <module>
# ----> 1 img = open_image('../input/test_images/ffec9a18a3ce.png')
#       2 img
#
# d:\installed_softwares\miniconda\envs\fastai\lib\site-packages\fastai\vision\image.py in open_image(fn, div, convert_mode, cls, after_open)
#     396     with warnings.catch_warnings():
#     397         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 398         x = PIL.Image.open(fn).convert(convert_mode)
#     399     if after_open: x = after_open(x)
#     400     x = pil2tensor(x,np.float32)
#
# ~\AppData\Roaming\Python\Python37\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# ...

# %%
learn = load_learner(path)

# %%
pred_class, pred_idx, outputs = learn.predict(img)
pred_class
